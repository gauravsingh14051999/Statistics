# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('alphabet_stock_data.csv')

# %%
#Write a Pandas program to create a line plot of the opening, closing stock prices of Alphabet Inc. between two specific dates

# %%
df.head()
# Out:
#         Date         Open         High          Low        Close    Adj Close  \
# 0 2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995  1105.619995
# 1 2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966  1120.839966
# 2 2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005  1097.880005
# 3 2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044  1186.920044
# 4 2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010  1186.510010
#
#     Volume
# 0  2343100
# 1  1964900
# 2  2313400
# 3  2664700
# 4  2387300

# %%
df1=df[['Date','Open','Close']]

# %%
df1
# Out:
#           Date         Open        Close
# 0   2020-04-01  1122.000000  1105.619995
# 1   2020-04-02  1098.260010  1120.839966
# 2   2020-04-03  1119.015015  1097.880005
# 3   2020-04-06  1138.000000  1186.920044
# 4   2020-04-07  1221.000000  1186.510010
# ..         ...          ...          ...
# 122 2020-09-24  1411.030029  1428.290039
# 123 2020-09-25  1432.630005  1444.959961
# 124 2020-09-28  1474.209961  1464.520020
# 125 2020-09-29  1470.390015  1469.329956
# 126 2020-09-30  1466.800049  1469.599976
#
# [127 rows x 3 columns]

# %%
chk=np.where((df1['Date']>='2020-04-01') & (df1['Date']<='2020-04-13'))
df2=df1.loc[chk]
df2
# Out:
#         Date         Open        Close
# 0 2020-04-01  1122.000000  1105.619995
# 1 2020-04-02  1098.260010  1120.839966
# 2 2020-04-03  1119.015015  1097.880005
# 3 2020-04-06  1138.000000  1186.920044
# 4 2020-04-07  1221.000000  1186.510010
# 5 2020-04-08  1206.500000  1210.280029
# 6 2020-04-09  1224.079956  1211.449951
# 7 2020-04-13  1209.180054  1217.560059

# %%
df2.plot()
# Out:
# <AxesSubplot:>

# %%
#2.Write a Pandas program to create a line plot of the historical stock prices of Alphabet Inc. between two specific dates.

# %%
import matplotlib.pyplot as plt
df=pd.read_csv('alphabet_stock_data.csv')
df1=df[['Date','Close']]
df2=np.where((df1['Date']>='2020-04-01') & (df1['Date']<='2020-09-30'))
df3=df1.iloc[df2]
plt.suptitle('Stock prices of Alphabet Inc.,\n01-04-2020 to 30-09-2020', \
                 fontsize=18, color='black')
plt.xlabel("Date",fontsize=16, color='black')
plt.ylabel("$ price", fontsize=16, color='black')
df3['Close'].plot(color='green')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='$ price'>

# %%
#3.Write a Pandas program to create a bar plot of the trading volume of Alphabet Inc. stock between two specific dates.

# %%
import matplotlib.pyplot as plt
df=pd.read_csv('alphabet_stock_data.csv')
df1=df[['Date','Volume']]
df2=np.where((df1['Date']>='2020-04-01') & (df1['Date']<='2020-04-12'))
df3=df1.iloc[df2]
plt.suptitle('Stock prices of Alphabet Inc.,\n01-04-2020 to 30-09-2020', \
                 fontsize=18, color='black')
plt.xlabel("Date",fontsize=16, color='black')
plt.ylabel("$ price", fontsize=16, color='black')
df3['Volume'].plot.bar(color='green')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='$ price'>

# %%
#4.
import matplotlib.pyplot as plt
df=pd.read_csv('alphabet_stock_data.csv')
df1=df[['Date','Open','Close']]
df2=np.where((df1['Date']>='2020-04-01') & (df1['Date']<='2020-04-12'))
df3=df1.iloc[df2]

df3.plot.bar()
# Out:
# <AxesSubplot:>

# %%
#5.
import matplotlib.pyplot as plt
df=pd.read_csv('alphabet_stock_data.csv')
df1=df[['Date','Open','Close']]
df2=np.where((df1['Date']>='2020-04-01') & (df1['Date']<='2020-04-12'))
df3=df1.iloc[df2]

df3.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
#6.Write a Pandas program to create a horizontal stacked bar plot 
#of opening, closing stock prices of Alphabet Inc. between two specific dates. 

import matplotlib.pyplot as plt
df=pd.read_csv('alphabet_stock_data.csv')
df1=df[['Date','Open','Close']]
df2=np.where((df1['Date']>='2020-04-01') & (df1['Date']<='2020-04-12'))
df3=df1.iloc[df2]

df3.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %%
#7.Write a Pandas program to create a histograms plot of opening, closing, high, 
#low stock prices of Alphabet Inc. between two specific dates. 

import matplotlib.pyplot as plt
df=pd.read_csv('alphabet_stock_data.csv')
df1=df[['Date','Open','Close','High','Low']]
df2=np.where((df1['Date']>='2020-04-01') & (df1['Date']<='2020-09-30'))
df3=df1.iloc[df2]

df3.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#8
# Write a Pandas program to create a stacked histograms plot of opening,
# closing, high, low stock prices of Alphabet Inc. between two specific dates.

import matplotlib.pyplot as plt
df=pd.read_csv('alphabet_stock_data.csv')
df1=df[['Date','Open','Close','High','Low']]
df2=np.where((df1['Date']>='2020-04-01') & (df1['Date']<='2020-09-30'))
df3=df1.iloc[df2]

df3.plot.hist(stacked=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#9.
import matplotlib.pyplot as plt
df=pd.read_csv('alphabet_stock_data.csv')
df1=df[['Date','Open']]
df2=np.where((df1['Date']>='2020-04-01') & (df1['Date']<='2020-09-30'))
df3=df1.iloc[df2]

df3.plot.hist(orientation='horizontal',cumulative=True)
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
#10.
# Write a Pandas program to create a stacked histograms plot of opening, closing, high, 
# low stock prices of Alphabet Inc. between two specific dates with more bins. 

import matplotlib.pyplot as plt
df=pd.read_csv('alphabet_stock_data.csv')
df1=df[['Date','Open','Close','High','Low']]
df2=np.where((df1['Date']>='2020-04-01') & (df1['Date']<='2020-09-30'))
df3=df1.iloc[df2]

df3.plot.hist(stacked=True,bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#11.Write a Pandas program to create a stacked histograms plot with more bins of opening, 
#closing, high, low stock prices of Alphabet Inc. between two specific dates. 
import matplotlib.pyplot as plt
df=pd.read_csv('alphabet_stock_data.csv')
df1=df[['Date','Open','Close','High','Low']]
df2=np.where((df1['Date']>='2020-04-01') & (df1['Date']<='2020-09-30'))
df3=df1.iloc[df2]

df3.plot.hist(stacked=True,bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#12.Write a Pandas program to create a plot of stock price and trading volume of Alphabet Inc. between two specific dates. 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df=pd.read_csv('alphabet_stock_data.csv')
df1=df[['Date','Close','High','Volume']]
df2=np.where((df1['Date']>='2020-04-01') & (df1['Date']<='2020-09-30'))
df3=df1.iloc[df2]

df3.plot(subplots = True);

# %%
#13. Write a Pandas program to create a plot of Open, High, Low, Close, Adjusted Closing prices and
# Volume of Alphabet Inc. between two specific dates. 

import matplotlib.pyplot as plt
df=pd.read_csv('alphabet_stock_data.csv')
#df1=df[['Date','Open','Close','High','Low','Adj Close','Volume']]
df2=np.where((df['Date']>='2020-04-01') & (df['Date']<='2020-09-30'))
df3=df.iloc[df2]

df3.plot(subplots = True);

# %%
#14.
# Write a Pandas program to create a plot of adjusted closing prices, thirty days and forty days 
# simple moving average of Alphabet Inc.  between two specific dates. 

import matplotlib.pyplot as plt
df=pd.read_csv('alphabet_stock_data.csv')
df1=df[['Date','Adj Close']]
df2=np.where((df1['Date']>='2020-04-01') & (df1['Date']<='2020-09-30'))
df3=df1.iloc[df2]
df3['SMA_30_days'] = df3.iloc[:,1].rolling(window=30).mean() 
df3['SMA_40_days'] = df3.iloc[:,1].rolling(window=40).mean()
plt.figure(figsize=[8,6])
plt.grid(True)
plt.title('Historical stock prices of Alphabet Inc. [01-04-2020 to 30-09-2020]\n',fontsize=18, color='black')
plt.plot(df3['Adj Close'],label='Adjusted Closing Price', color='black')
plt.plot(df3['SMA_30_days'],label='30 days simple moving average', color='red')
plt.plot(df3['SMA_40_days'],label='40 days simple moving average', color='green')
plt.legend(loc=2)
plt.show()

# %%
#15.Write a Pandas program to create a plot of adjusted closing prices, 30 days simple 
#moving average and exponential moving average of Alphabet Inc. between two specific dates.

import matplotlib.pyplot as plt
df=pd.read_csv('alphabet_stock_data.csv')
df1=df[['Date','Adj Close']]
df2=np.where((df1['Date']>='2020-04-01') & (df1['Date']<='2020-09-30'))
df3=df1.iloc[df2]
df3['30_days']=df3.iloc[:,1].rolling(window=30).mean()
df3['20_days'] = df3.iloc[:,1].ewm(span=20,adjust=False).mean()

plt.grid(True)
plt.title('Historical stock prices of Alphabet Inc. [01-04-2020 to 30-09-2020]\n',fontsize=18, color='black')
plt.plot(df3['Adj Close'],label='Adjusted Closing Price', color='blue')
plt.plot(df3['30_days'],label='30 days simple moving average', color='red')
plt.plot(df3['20_days'],label='20 days exponential moving average', color='green')
plt.legend(loc=2)
plt.show()

# %%
#16. Write a Pandas program to create a scatter plot of the trading volume/stock prices of Alphabet Inc. 
#stock between two specific dates.

import matplotlib.pyplot as plt
df=pd.read_csv('alphabet_stock_data.csv')
df1=df[['Close','Volume']]
df2=np.where((df['Date']>='2020-04-01') & (df['Date']<='2020-09-30'))
df3=df1.iloc[df2]
x=['Close']
y=['Volume']
df3.plot.scatter(x,y);

plt.grid(True)
plt.title('Trading Volume/Price of Alphabet Inc. stock,\n01-04-2020 to 30-09-2020', fontsize=14, color='black')
plt.xlabel("Stock Price",fontsize=12, color='black')
plt.ylabel("Trading Volume", fontsize=12, color='black') 
plt.show()
